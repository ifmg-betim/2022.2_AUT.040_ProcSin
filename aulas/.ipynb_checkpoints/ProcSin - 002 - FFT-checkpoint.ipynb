# %%
#importa as bibliotecas
import numpy as np, scipy as sp, matplotlib.pyplot as plt

#cria vetor tempo
N = 150 #numero de amostras
T = 0.5 # periodo de amostragem
# T = 0.45454545454545454545454545454545454545 # periodo de amostragem
t0 = 0 # tempo inicial
t = np.linspace(t0, (N-1)*T, N) # vetor tempo (opcao 1)
t = np.arange(t0, N*T, T) # vetor tempo (opcao 2)

# criando o vetor SINAL
x = np.sin(0.44*np.pi*t) + 0.5*np.sin(np.pi*t) + 1 # T=4.54

# grafico do sinal
plt.figure(figsize=(8,2))
plt.plot(x);
plt.title("Sinal $x[n]$")
plt.xlabel("amostras [$n$]")
plt.ylabel("$x[n]$")

plt.figure(figsize=(8,2))
plt.plot(t, x);
plt.title("Sinal $x(nT)$")
plt.xlabel("segundos [$nT$]")
plt.ylabel("$x[nT]$")
plt.xlim(0, 12);

# %%
# Fazer a FFT (Fast Fourier Transform) do sinal
from scipy.fft import fft

Nfft = 1000 #numero de pontos na transformada de fourier

X_f = fft(x, n=Nfft)
X_f = X_f/N # corrige amplitude do sinal
X_f = X_f[:Nfft//2] # suprime os espelhamentos do sinal na freq
X_f[1:] = 2*X_f[1:] # dobra a amplitude das freqs diferente de zero
# f0 = 1/(Nfft*T) #freq em Hz
# fHz = np.arange(Nfft)*f0 #freq em Hz
# fHz = fHz[:Nfft//2]
# w0 = 2*np.pi/(Nfft*T) #freq em rad/s
# wRad = np.arange(Nfft)*w0 #freq em rad/s
w0 = 2*np.pi/(Nfft) #freq em rad/amostra
wRad = np.arange(Nfft)*w0 #freq em rad/amostra
wRad = wRad[:Nfft//2]

# mag = np.abs(X_f) # modulo no dominio da frequencia
mag = 20*np.log10(np.abs(X_f)) # modulo no dominio da frequencia em dB
fase = np.angle(X_f, deg=1) # fase no dominio da frequencia

plt.figure(figsize=(8,2))
plt.plot(wRad, mag) #modulo
plt.xlabel("frequencias (rad/s)")
plt.ylabel("$|X_f(\omega)|_{dB}$")
plt.grid(1);

plt.figure(figsize=(8,2))
plt.plot(wRad, fase) #fase
plt.xlabel("frequencias (rad/s)")
plt.ylabel("$\measuredangle X_f(\omega)$ (graus)")
plt.grid(1);

# %%
.44*np.pi
# Out:
# 1.382300767579509
